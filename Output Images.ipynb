# %%
using FileIO, DelimitedFiles, PyPlot
io = open(string("/rc_scratch/mawa7160/Tests/state_1000_9000.txt"), "r")
start  = readdlm(io, '\t', Float64, '\n')
imshow(start)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x2b1f1497c978>

# %%
using FileIO, DelimitedFiles, PyPlot
io = open(string("/rc_scratch/mawa7160/Tests/state_2000_9000.txt"), "r")
start  = readdlm(io, '\t', Float64, '\n')
imshow(start)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x2b1f14a2c4e0>

# %%
using FileIO, DelimitedFiles, PyPlot
io = open(string("/rc_scratch/mawa7160/Tests/state_3000_9000.txt"), "r")
start  = readdlm(io, '\t', Float64, '\n')
imshow(start)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x2b1f14a9a438>

# %%
using FileIO, DelimitedFiles, PyPlot
io = open(string("/rc_scratch/mawa7160/Tests/state_4000_9000.txt"), "r")
start  = readdlm(io, '\t', Float64, '\n')
imshow(start)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x2b1f14b07128>

# %%
using FileIO, DelimitedFiles, PyPlot
io = open(string("/rc_scratch/mawa7160/Tests/state_4500_9000.txt"), "r")
start  = readdlm(io, '\t', Float64, '\n')
imshow(start)
plt.savefig("/projects/mawa7160/Tests/4500.png")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
using FileIO, DelimitedFiles, PyPlot, FFTW
include("Initialize.jl")
io = open(string("/projects/mawa7160/Tests/state_4500_9000.txt"), "r")
start  = readdlm(io, '\t', Float64, '\n')
close(io)
q = FFTW.rfft(start, 1:2);
u_start = zeros(ComplexF64,641,1280,2)
u_start[:,:,1] = q
u_start[:,:,2] = q
# Out:
# (641, 1280, 2)
# (641, 1280, 2)
# WARNING: replacing module Init.
